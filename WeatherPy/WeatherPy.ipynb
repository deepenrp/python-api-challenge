# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key
from api_keys import g_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 615

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Base URL to work off                         
base_url = "http://api.openweathermap.org/data/2.5/weather?"

# Counter to go through data
record = 0
sets = 1

# Create DataFrame
weather_df = pd.DataFrame({"City": cities})

weather_df["Country"] = ""
weather_df["Date"] = ""      
weather_df["Latitude"] = ""
weather_df["Longitude"] = ""
weather_df["Cloudiness (%)"] = ""
weather_df["Humidity (%)"] = ""
weather_df["Max Temp (F)"] = ""
weather_df["Wind Speed (mph)"] = ""


# Interate through Cities and retrieve data
print("Beginning Data Retrieval")
print("-----------------------------")


for index, row in weather_df.iterrows():
    
    city = row["City"]
    
    query_url = base_url + "appid=" + weather_api_key + "&q=" + city
    weather_response = requests.get(query_url).json()
 
    try:
        print(f"Processing Record {record}  of Set {sets} | {city}.")
        #print (query_url) 
        
        weather_df.loc[index, "Country"] = weather_response["sys"]["country"]     
        weather_df.loc[index, "Date"] = datetime.datetime.fromtimestamp(weather_response["dt"])
        weather_df.loc[index, "Latitude"] = weather_response["coord"]["lat"]
        weather_df.loc[index, "Longitude"] = weather_response["coord"]["lon"]
        weather_df.loc[index, "Cloudiness (%)"] = weather_response["clouds"]["all"]
        weather_df.loc[index, "Humidity (%)"] = weather_response["main"]["humidity"]
        weather_df.loc[index, "Max Temp (F)"] = 1.8 * (weather_response["main"]["temp_max"] - 273) + 32
        weather_df.loc[index, "Wind Speed (mph)"] = weather_response["wind"]["speed"]
               
    except:
        print(f"City not found...skipping {city}.")
        #print (query_url) 
        
    
    record = record + 1
    if record == 50:
        record = 0
        sets = sets + 1 

print("-----------------------------")        
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0  of Set 1 | san quintin.
# Processing Record 1  of Set 1 | rikitea.
# Processing Record 2  of Set 1 | katsuura.
# Processing Record 3  of Set 1 | mataura.
# Processing Record 4  of Set 1 | camopi.
# Processing Record 5  of Set 1 | bambous virieux.
# Processing Record 6  of Set 1 | vaini.
# Processing Record 7  of Set 1 | barentsburg.
# City not found...skipping barentsburg.
# Processing Record 8  of Set 1 | qaanaaq.
# Processing Record 9  of Set 1 | salinas.
# Processing Record 10  of Set 1 | moyale.
# Processing Record 11  of Set 1 | carnarvon.
# Processing Record 12  of Set 1 | puerto ayora.
# Processing Record 13  of Set 1 | nikolskoye.
# Processing Record 14  of Set 1 | coihaique.
# Processing Record 15  of Set 1 | belushya guba.
# City not found...skipping belushya guba.
# Processing Record 16  of Set 1 | gat.
# Processing Record 17  of Set 1 | kulhudhuffushi.
# Processing Record 18  of Set 1 | bredasdorp.
# Processing Record 19  of Set 1 | tacoronte.
# Processing Record 20  of Set 1 | illoqqortoormiut.
# City not found...skipping illoqqortoormiut.
# Processing Record 21  of Set 1 | te anau.
# Processing Record 22  of Set 1 | agen.
# Processing Record 23  of Set 1 | albany.
# Processing Record 24  of Set 1 | champerico.
# Processing Record 25  of Set 1 | namibe.
# Processing Record 26  of Set 1 | cayenne.
# Processing Record 27  of Set 1 | tual.
# Processing Record 28  of Set 1 | hermanus.
# Processing Record 29  of Set 1 | alofi.
# Processing Record 30  of Set 1 | halalo.
# City not found...skipping halalo.
# Processing Record 31  of Set 1 | east london.
# Processing Record 32  of Set 1 | avarua.
# Processing Record 33  of Set 1 | souillac.
# Processing Record 34  of Set 1 | gorontalo.
# Processing Record 35  of Set 1 | new norfolk.
# Processing Record 36  of Set 1 | mrirt.
# City not found...skipping mrirt.
# Processing Record 37  of Set 1 | jamestown.
# Processing Record 38  of Set 1 | port alfred.
# Processing Record 39  of Set 1 | kasongo-lunda.
# Processing Record 40  of Set 1 | busselton.
# Processing Record 41  of Set 1 | dikson.
# Processing Record 42  of Set 1 | kabanjahe.
# Processing Record 43  of Set 1 | clyde river.
# Processing Record 44  of Set 1 | cabra.
# Processing Record 45  of Set 1 | hilo.
# Processing Record 46  of Set 1 | bluff.
# Processing Record 47  of Set 1 | punta arenas.
# Processing Record 48  of Set 1 | tlahualilo.
# City not found...skipping tlahualilo.
# Processing Record 49  of Set 1 | tsihombe.
# City not found...skipping tsihombe.
# Processing Record 0  of Set 2 | atuona.
# Processing Record 1  of Set 2 | kaitangata.
# Processing Record 2  of Set 2 | hobart.
# Processing Record 3  of Set 2 | mizdah.
# Processing Record 4  of Set 2 | bjornevatn.
# Processing Record 5  of Set 2 | lebu.
# Processing Record 6  of Set 2 | caravelas.
# Processing Record 7  of Set 2 | phek.
# Processing Record 8  of Set 2 | cherskiy.
# Processing Record 9  of Set 2 | uusikaupunki.
# Processing Record 10  of Set 2 | sinnamary.
# Processing Record 11  of Set 2 | la ronge.
# Processing Record 12  of Set 2 | kapaa.
# Processing Record 13  of Set 2 | mahebourg.
# Processing Record 14  of Set 2 | burriana.
# Processing Record 15  of Set 2 | meulaboh.
# Processing Record 16  of Set 2 | ust-tsilma.
# Processing Record 17  of Set 2 | attawapiskat.
# City not found...skipping attawapiskat.
# Processing Record 18  of Set 2 | mount isa.
# Processing Record 19  of Set 2 | skelleftea.
# Processing Record 20  of Set 2 | hithadhoo.
# Processing Record 21  of Set 2 | hohhot.
# Processing Record 22  of Set 2 | ambilobe.
# Processing Record 23  of Set 2 | butaritari.
# Processing Record 24  of Set 2 | tuktoyaktuk.
# Processing Record 25  of Set 2 | pierre.
# Processing Record 26  of Set 2 | fortuna.
# Processing Record 27  of Set 2 | egvekinot.
# Processing Record 28  of Set 2 | warqla.
# City not found...skipping warqla.
# Processing Record 29  of Set 2 | xining.
# Processing Record 30  of Set 2 | port blair.
# Processing Record 31  of Set 2 | lata.
# Processing Record 32  of Set 2 | barrow.
# Processing Record 33  of Set 2 | bairiki.
# City not found...skipping bairiki.
# Processing Record 34  of Set 2 | khatanga.
# Processing Record 35  of Set 2 | zemio.
# Processing Record 36  of Set 2 | castro.
# Processing Record 37  of Set 2 | bilibino.
# Processing Record 38  of Set 2 | thompson.
# Processing Record 39  of Set 2 | cabo san lucas.
# Processing Record 40  of Set 2 | vaitape.
# Processing Record 41  of Set 2 | provideniya.
# Processing Record 42  of Set 2 | pevek.
# Processing Record 43  of Set 2 | yellowknife.
# Processing Record 44  of Set 2 | shakawe.
# Processing Record 45  of Set 2 | bethel.
# Processing Record 46  of Set 2 | norsup.
# Processing Record 47  of Set 2 | kovacica.
# Processing Record 48  of Set 2 | geraldton.
# Processing Record 49  of Set 2 | airai.
# Processing Record 0  of Set 3 | atar.
# Processing Record 1  of Set 3 | abnub.
# Processing Record 2  of Set 3 | ushuaia.
# Processing Record 3  of Set 3 | narsaq.
# Processing Record 4  of Set 3 | upernavik.
# Processing Record 5  of Set 3 | nizhneyansk.
# City not found...skipping nizhneyansk.
# Processing Record 6  of Set 3 | issaquah.
# Processing Record 7  of Set 3 | naze.
# Processing Record 8  of Set 3 | mana.
# Processing Record 9  of Set 3 | binzhou.
# Processing Record 10  of Set 3 | maniitsoq.
# Processing Record 11  of Set 3 | pisco.
# Processing Record 12  of Set 3 | georgetown.
# Processing Record 13  of Set 3 | sola.
# Processing Record 14  of Set 3 | komsomolskiy.
# Processing Record 15  of Set 3 | guildford.
# Processing Record 16  of Set 3 | waddan.
# Processing Record 17  of Set 3 | aklavik.
# Processing Record 18  of Set 3 | nome.
# Processing Record 19  of Set 3 | iacu.
# Processing Record 20  of Set 3 | keti bandar.
# Processing Record 21  of Set 3 | lolua.
# City not found...skipping lolua.
# Processing Record 22  of Set 3 | neustadt.
# Processing Record 23  of Set 3 | salvador.
# Processing Record 24  of Set 3 | tura.
# Processing Record 25  of Set 3 | vaitupu.
# City not found...skipping vaitupu.
# Processing Record 26  of Set 3 | zhigansk.
# Processing Record 27  of Set 3 | paysandu.
# Processing Record 28  of Set 3 | port lincoln.
# Processing Record 29  of Set 3 | san cristobal.
# Processing Record 30  of Set 3 | kahului.
# Processing Record 31  of Set 3 | kemijarvi.
# City not found...skipping kemijarvi.
# Processing Record 32  of Set 3 | kodiak.
# Processing Record 33  of Set 3 | cape town.
# Processing Record 34  of Set 3 | samusu.
# City not found...skipping samusu.
# Processing Record 35  of Set 3 | rio gallegos.
# Processing Record 36  of Set 3 | el balyana.
# City not found...skipping el balyana.
# Processing Record 37  of Set 3 | milagres.
# Processing Record 38  of Set 3 | longyearbyen.
# Processing Record 39  of Set 3 | kosjeric.
# Processing Record 40  of Set 3 | jevargi.
# Processing Record 41  of Set 3 | maragogi.
# Processing Record 42  of Set 3 | rajapalaiyam.
# Processing Record 43  of Set 3 | ostrovnoy.
# Processing Record 44  of Set 3 | oktyabrskiy.
# Processing Record 45  of Set 3 | umm kaddadah.
# Processing Record 46  of Set 3 | stuttgart.
# Processing Record 47  of Set 3 | tynda.
# Processing Record 48  of Set 3 | saint andrews.
# Processing Record 49  of Set 3 | bandarbeyla.
# Processing Record 0  of Set 4 | huatulco.
# Processing Record 1  of Set 4 | amderma.
# City not found...skipping amderma.
# Processing Record 2  of Set 4 | abu samrah.
# Processing Record 3  of Set 4 | fort frances.
# Processing Record 4  of Set 4 | poum.
# Processing Record 5  of Set 4 | ribeira grande.
# Processing Record 6  of Set 4 | saint-philippe.
# Processing Record 7  of Set 4 | bengkulu.
# City not found...skipping bengkulu.
# Processing Record 8  of Set 4 | ureshino.
# Processing Record 9  of Set 4 | port-gentil.
# Processing Record 10  of Set 4 | taolanaro.
# City not found...skipping taolanaro.
# Processing Record 11  of Set 4 | batagay-alyta.
# Processing Record 12  of Set 4 | karaul.
# City not found...skipping karaul.
# Processing Record 13  of Set 4 | qinhuangdao.
# Processing Record 14  of Set 4 | mar del plata.
# Processing Record 15  of Set 4 | khormuj.
# City not found...skipping khormuj.
# Processing Record 16  of Set 4 | jalu.
# Processing Record 17  of Set 4 | lishan.
# Processing Record 18  of Set 4 | esmeraldas.
# Processing Record 19  of Set 4 | aleksandro-nevskiy.
# Processing Record 20  of Set 4 | stoyba.
# City not found...skipping stoyba.
# Processing Record 21  of Set 4 | esperance.
# Processing Record 22  of Set 4 | hofn.
# Processing Record 23  of Set 4 | longlac.
# City not found...skipping longlac.
# Processing Record 24  of Set 4 | astana.
# Processing Record 25  of Set 4 | bud.
# Processing Record 26  of Set 4 | tsabong.
# Processing Record 27  of Set 4 | polis.
# Processing Record 28  of Set 4 | mumford.
# Processing Record 29  of Set 4 | lima.
# Processing Record 30  of Set 4 | sentyabrskiy.
# City not found...skipping sentyabrskiy.
# Processing Record 31  of Set 4 | thetford mines.
# Processing Record 32  of Set 4 | mahibadhoo.
# Processing Record 33  of Set 4 | korla.
# City not found...skipping korla.
# Processing Record 34  of Set 4 | saskylakh.
# Processing Record 35  of Set 4 | ust-kamchatsk.
# City not found...skipping ust-kamchatsk.
# Processing Record 36  of Set 4 | kyabe.
# Processing Record 37  of Set 4 | jelling.
# Processing Record 38  of Set 4 | juneau.
# Processing Record 39  of Set 4 | palabuhanratu.
# City not found...skipping palabuhanratu.
# Processing Record 40  of Set 4 | kaeo.
# Processing Record 41  of Set 4 | bollnas.
# Processing Record 42  of Set 4 | bayburt.
# Processing Record 43  of Set 4 | miri.
# Processing Record 44  of Set 4 | huarmey.
# Processing Record 45  of Set 4 | vardo.
# Processing Record 46  of Set 4 | laguna.
# Processing Record 47  of Set 4 | ginda.
# Processing Record 48  of Set 4 | itarema.
# Processing Record 49  of Set 4 | evensk.
# Processing Record 0  of Set 5 | villamontes.
# Processing Record 1  of Set 5 | sioux lookout.
# Processing Record 2  of Set 5 | dunmore.
# Processing Record 3  of Set 5 | faya.
# Processing Record 4  of Set 5 | monaco-ville.
# Processing Record 5  of Set 5 | kalmunai.
# Processing Record 6  of Set 5 | kavaratti.
# Processing Record 7  of Set 5 | tungkang.
# City not found...skipping tungkang.
# Processing Record 8  of Set 5 | sept-iles.
# Processing Record 9  of Set 5 | vila velha.
# Processing Record 10  of Set 5 | lianyuan.
# Processing Record 11  of Set 5 | olafsvik.
# City not found...skipping olafsvik.
# Processing Record 12  of Set 5 | muroto.
# Processing Record 13  of Set 5 | entre rios.
# Processing Record 14  of Set 5 | salalah.
# Processing Record 15  of Set 5 | itarantim.
# Processing Record 16  of Set 5 | petropavlovsk-kamchatskiy.
# Processing Record 17  of Set 5 | vao.
# Processing Record 18  of Set 5 | port shepstone.
# Processing Record 19  of Set 5 | pailon.
# Processing Record 20  of Set 5 | bam.
# Processing Record 21  of Set 5 | paita.
# Processing Record 22  of Set 5 | iqaluit.
# Processing Record 23  of Set 5 | rantepao.
# Processing Record 24  of Set 5 | mut.
# Processing Record 25  of Set 5 | agadez.
# Processing Record 26  of Set 5 | nishihara.
# Processing Record 27  of Set 5 | korgen.
# Processing Record 28  of Set 5 | atbasar.
# Processing Record 29  of Set 5 | heilbron.
# Processing Record 30  of Set 5 | murgab.
# Processing Record 31  of Set 5 | chokurdakh.
# Processing Record 32  of Set 5 | nemuro.
# Processing Record 33  of Set 5 | yanan.
# City not found...skipping yanan.
# Processing Record 34  of Set 5 | vuktyl.
# Processing Record 35  of Set 5 | gilgil.
# City not found...skipping gilgil.
# Processing Record 36  of Set 5 | koslan.
# Processing Record 37  of Set 5 | honiara.
# Processing Record 38  of Set 5 | bereda.
# Processing Record 39  of Set 5 | ternate.
# Processing Record 40  of Set 5 | luau.
# Processing Record 41  of Set 5 | diamond harbour.
# Processing Record 42  of Set 5 | ahipara.
# Processing Record 43  of Set 5 | mys shmidta.
# City not found...skipping mys shmidta.
# Processing Record 44  of Set 5 | port elizabeth.
# Processing Record 45  of Set 5 | vung tau.
# Processing Record 46  of Set 5 | chuy.
# Processing Record 47  of Set 5 | grand river south east.
# City not found...skipping grand river south east.
# Processing Record 48  of Set 5 | gambela.
# Processing Record 49  of Set 5 | saint george.
# Processing Record 0  of Set 6 | kawalu.
# Processing Record 1  of Set 6 | yulara.
# Processing Record 2  of Set 6 | severo-kurilsk.
# Processing Record 3  of Set 6 | dolbeau.
# City not found...skipping dolbeau.
# Processing Record 4  of Set 6 | tacuarembo.
# Processing Record 5  of Set 6 | grandola.
# Processing Record 6  of Set 6 | tasiilaq.
# Processing Record 7  of Set 6 | baie-saint-paul.
# Processing Record 8  of Set 6 | bourail.
# Processing Record 9  of Set 6 | marcona.
# City not found...skipping marcona.
# Processing Record 10  of Set 6 | sitka.
# Processing Record 11  of Set 6 | inhuma.
# Processing Record 12  of Set 6 | san patricio.
# Processing Record 13  of Set 6 | pombas.
# Processing Record 14  of Set 6 | vostok.
# Processing Record 15  of Set 6 | hualmay.
# Processing Record 16  of Set 6 | makakilo city.
# Processing Record 17  of Set 6 | sao filipe.
# Processing Record 18  of Set 6 | victoria.
# Processing Record 19  of Set 6 | yeppoon.
# Processing Record 20  of Set 6 | sabang.
# Processing Record 21  of Set 6 | locri.
# Processing Record 22  of Set 6 | calbuco.
# Processing Record 23  of Set 6 | umm lajj.
# Processing Record 24  of Set 6 | torbay.
# Processing Record 25  of Set 6 | ondorhaan.
# City not found...skipping ondorhaan.
# Processing Record 26  of Set 6 | patacamaya.
# Processing Record 27  of Set 6 | kloulklubed.
# Processing Record 28  of Set 6 | grand gaube.
# Processing Record 29  of Set 6 | ilulissat.
# Processing Record 30  of Set 6 | nuuk.
# Processing Record 31  of Set 6 | mugur-aksy.
# Processing Record 32  of Set 6 | batemans bay.
# Processing Record 33  of Set 6 | husavik.
# Processing Record 34  of Set 6 | matadi.
# Processing Record 35  of Set 6 | port augusta.
# Processing Record 36  of Set 6 | neuquen.
# Processing Record 37  of Set 6 | gerede.
# Processing Record 38  of Set 6 | garden city.
# Processing Record 39  of Set 6 | yangambi.
# Processing Record 40  of Set 6 | vilyuysk.
# Processing Record 41  of Set 6 | arraial do cabo.
# Processing Record 42  of Set 6 | liverpool.
# Processing Record 43  of Set 6 | maghama.
# City not found...skipping maghama.
# Processing Record 44  of Set 6 | pochutla.
# Processing Record 45  of Set 6 | pangody.
# Processing Record 46  of Set 6 | bilma.
# Processing Record 47  of Set 6 | toora-khem.
# Processing Record 48  of Set 6 | palmer.
# Processing Record 49  of Set 6 | bull savanna.
# Processing Record 0  of Set 7 | marawi.
# Processing Record 1  of Set 7 | chiang rai.
# Processing Record 2  of Set 7 | hihifo.
# City not found...skipping hihifo.
# Processing Record 3  of Set 7 | pacific grove.
# Processing Record 4  of Set 7 | diego de almagro.
# Processing Record 5  of Set 7 | chapais.
# Processing Record 6  of Set 7 | rungata.
# City not found...skipping rungata.
# Processing Record 7  of Set 7 | banepa.
# Processing Record 8  of Set 7 | kosa.
# Processing Record 9  of Set 7 | santa flavia.
# Processing Record 10  of Set 7 | tuggurt.
# City not found...skipping tuggurt.
# Processing Record 11  of Set 7 | bouake.
# Processing Record 12  of Set 7 | coahuayana.
# Processing Record 13  of Set 7 | ballymena.
# Processing Record 14  of Set 7 | manitouwadge.
# Processing Record 15  of Set 7 | krasnoselkup.
# City not found...skipping krasnoselkup.
# Processing Record 16  of Set 7 | oak ridge.
# Processing Record 17  of Set 7 | guerrero negro.
# Processing Record 18  of Set 7 | aitape.
# Processing Record 19  of Set 7 | krasnoshchekovo.
# Processing Record 20  of Set 7 | morro bay.
# Processing Record 21  of Set 7 | saint-michel-des-saints.
# Processing Record 22  of Set 7 | lazaro cardenas.
# Processing Record 23  of Set 7 | touros.
# Processing Record 24  of Set 7 | bijie.
# Processing Record 25  of Set 7 | slavonski brod.
# Processing Record 26  of Set 7 | leningradskiy.
# Processing Record 27  of Set 7 | tarudant.
# City not found...skipping tarudant.
# Processing Record 28  of Set 7 | malidong.
# Processing Record 29  of Set 7 | coulommiers.
# Processing Record 30  of Set 7 | pangnirtung.
# Processing Record 31  of Set 7 | banda aceh.
# Processing Record 32  of Set 7 | antofagasta.
# Processing Record 33  of Set 7 | gjirokaster.
# Processing Record 34  of Set 7 | harnai.
# Processing Record 35  of Set 7 | sabrum.
# Processing Record 36  of Set 7 | lodwar.
# Processing Record 37  of Set 7 | buritizeiro.
# Processing Record 38  of Set 7 | ayan.
# Processing Record 39  of Set 7 | campo de criptana.
# Processing Record 40  of Set 7 | grindavik.
# Processing Record 41  of Set 7 | tomatlan.
# Processing Record 42  of Set 7 | phan rang.
# City not found...skipping phan rang.
# Processing Record 43  of Set 7 | nieuw amsterdam.
# Processing Record 44  of Set 7 | tiksi.
# Processing Record 45  of Set 7 | honningsvag.
# Processing Record 46  of Set 7 | utiroa.
# City not found...skipping utiroa.
# Processing Record 47  of Set 7 | camacha.
# Processing Record 48  of Set 7 | eldorado.
# Processing Record 49  of Set 7 | realeza.
# Processing Record 0  of Set 8 | malinovskiy.
# Processing Record 1  of Set 8 | avera.
# Processing Record 2  of Set 8 | ponta do sol.
# Processing Record 3  of Set 8 | cremlingen.
# Processing Record 4  of Set 8 | vanimo.
# Processing Record 5  of Set 8 | marsh harbour.
# Processing Record 6  of Set 8 | kutum.
# Processing Record 7  of Set 8 | rio grande.
# Processing Record 8  of Set 8 | moron.
# Processing Record 9  of Set 8 | tuatapere.
# Processing Record 10  of Set 8 | fairbanks.
# Processing Record 11  of Set 8 | westport.
# Processing Record 12  of Set 8 | zhezkazgan.
# Processing Record 13  of Set 8 | blackwater.
# Processing Record 14  of Set 8 | tombouctou.
# Processing Record 15  of Set 8 | erenhot.
# Processing Record 16  of Set 8 | isangel.
# Processing Record 17  of Set 8 | xai-xai.
# Processing Record 18  of Set 8 | artyk.
# City not found...skipping artyk.
# Processing Record 19  of Set 8 | rocha.
# Processing Record 20  of Set 8 | necochea.
# Processing Record 21  of Set 8 | nouadhibou.
# Processing Record 22  of Set 8 | sisimiut.
# Processing Record 23  of Set 8 | umzimvubu.
# City not found...skipping umzimvubu.
# Processing Record 24  of Set 8 | lengshuitan.
# Processing Record 25  of Set 8 | nicoya.
# Processing Record 26  of Set 8 | nova vicosa.
# Processing Record 27  of Set 8 | northam.
# Processing Record 28  of Set 8 | can.
# Processing Record 29  of Set 8 | kruisfontein.
# Processing Record 30  of Set 8 | hamilton.
# Processing Record 31  of Set 8 | neiafu.
# Processing Record 32  of Set 8 | bac lieu.
# City not found...skipping bac lieu.
# Processing Record 33  of Set 8 | buckeye.
# Processing Record 34  of Set 8 | sangmelima.
# Processing Record 35  of Set 8 | shubarshi.
# Processing Record 36  of Set 8 | taoudenni.
# Processing Record 37  of Set 8 | port hardy.
# Processing Record 38  of Set 8 | green river.
# Processing Record 39  of Set 8 | ashqelon.
# Processing Record 40  of Set 8 | monte carmelo.
# Processing Record 41  of Set 8 | ligayan.
# Processing Record 42  of Set 8 | dalsingh sarai.
# Processing Record 43  of Set 8 | ola.
# Processing Record 44  of Set 8 | rapid valley.
# Processing Record 45  of Set 8 | tawnat.
# City not found...skipping tawnat.
# Processing Record 46  of Set 8 | eskisehir.
# Processing Record 47  of Set 8 | lorengau.
# Processing Record 48  of Set 8 | ancud.
# Processing Record 49  of Set 8 | wuwei.
# Processing Record 0  of Set 9 | maxixe.
# Processing Record 1  of Set 9 | aykhal.
# Processing Record 2  of Set 9 | juifang.
# City not found...skipping juifang.
# Processing Record 3  of Set 9 | broome.
# Processing Record 4  of Set 9 | panjakent.
# Processing Record 5  of Set 9 | muhos.
# Processing Record 6  of Set 9 | khonuu.
# City not found...skipping khonuu.
# Processing Record 7  of Set 9 | kamenskoye.
# City not found...skipping kamenskoye.
# Processing Record 8  of Set 9 | guiren.
# Processing Record 9  of Set 9 | sorland.
# Processing Record 10  of Set 9 | satitoa.
# City not found...skipping satitoa.
# Processing Record 11  of Set 9 | waingapu.
# Processing Record 12  of Set 9 | chaplynka.
# Processing Record 13  of Set 9 | galgani.
# City not found...skipping galgani.
# Processing Record 14  of Set 9 | hutchinson.
# Processing Record 15  of Set 9 | kavieng.
# Processing Record 16  of Set 9 | qui nhon.
# City not found...skipping qui nhon.
# Processing Record 17  of Set 9 | solbjerg.
# Processing Record 18  of Set 9 | kuytun.
# Processing Record 19  of Set 9 | chipinge.
# Processing Record 20  of Set 9 | mezen.
# Processing Record 21  of Set 9 | ambunti.
# Processing Record 22  of Set 9 | muncar.
# Processing Record 23  of Set 9 | hasaki.
# Processing Record 24  of Set 9 | calama.
# Processing Record 25  of Set 9 | berlevag.
# Processing Record 26  of Set 9 | asau.
# City not found...skipping asau.
# Processing Record 27  of Set 9 | teguajinal.
# Processing Record 28  of Set 9 | rosendal.
# Processing Record 29  of Set 9 | mandurah.
# Processing Record 30  of Set 9 | verkhoyansk.
# Processing Record 31  of Set 9 | nanortalik.
# Processing Record 32  of Set 9 | nouakchott.
# Processing Record 33  of Set 9 | saleaula.
# City not found...skipping saleaula.
# Processing Record 34  of Set 9 | znamenskoye.
# Processing Record 35  of Set 9 | dzilam gonzalez.
# Processing Record 36  of Set 9 | rio branco.
# Processing Record 37  of Set 9 | namatanai.
# Processing Record 38  of Set 9 | riesa.
# Processing Record 39  of Set 9 | mogadishu.
# Processing Record 40  of Set 9 | hirara.
# Processing Record 41  of Set 9 | edd.
# Processing Record 42  of Set 9 | klaksvik.
# Processing Record 43  of Set 9 | beyneu.
# Processing Record 44  of Set 9 | cabedelo.
# Processing Record 45  of Set 9 | ust-maya.
# Processing Record 46  of Set 9 | bima.
# Processing Record 47  of Set 9 | dunda.
# Processing Record 48  of Set 9 | wadi.
# Processing Record 49  of Set 9 | plettenberg bay.
# Processing Record 0  of Set 10 | nha trang.
# Processing Record 1  of Set 10 | kamaishi.
# Processing Record 2  of Set 10 | omboue.
# Processing Record 3  of Set 10 | yar-sale.
# Processing Record 4  of Set 10 | hay river.
# Processing Record 5  of Set 10 | lagoa.
# Processing Record 6  of Set 10 | killybegs.
# Processing Record 7  of Set 10 | gemena.
# Processing Record 8  of Set 10 | raudeberg.
# Processing Record 9  of Set 10 | butterworth.
# Processing Record 10  of Set 10 | natal.
# Processing Record 11  of Set 10 | biak.
# Processing Record 12  of Set 10 | chagda.
# City not found...skipping chagda.
# Processing Record 13  of Set 10 | jabinyanah.
# Processing Record 14  of Set 10 | barra do corda.
# Processing Record 15  of Set 10 | san policarpo.
# Processing Record 16  of Set 10 | wajima.
# Processing Record 17  of Set 10 | haines junction.
# Processing Record 18  of Set 10 | sambava.
# Processing Record 19  of Set 10 | semey.
# Processing Record 20  of Set 10 | hami.
# Processing Record 21  of Set 10 | corat.
# Processing Record 22  of Set 10 | santa rosa.
# Processing Record 23  of Set 10 | grootfontein.
# Processing Record 24  of Set 10 | newport.
# Processing Record 25  of Set 10 | timizart.
# Processing Record 26  of Set 10 | ucluelet.
# Processing Record 27  of Set 10 | mega.
# Processing Record 28  of Set 10 | pedernales.
# Processing Record 29  of Set 10 | constitucion.
# Processing Record 30  of Set 10 | herat.
# Processing Record 31  of Set 10 | karaj.
# Processing Record 32  of Set 10 | haysville.
# Processing Record 33  of Set 10 | cockburn town.
# Processing Record 34  of Set 10 | vadso.
# Processing Record 35  of Set 10 | soyo.
# Processing Record 36  of Set 10 | aksarka.
# Processing Record 37  of Set 10 | olean.
# Processing Record 38  of Set 10 | owando.
# Processing Record 39  of Set 10 | lodja.
# Processing Record 40  of Set 10 | sao felix do xingu.
# Processing Record 41  of Set 10 | mata.
# Processing Record 42  of Set 10 | opuwo.
# Processing Record 43  of Set 10 | dawson creek.
# Processing Record 44  of Set 10 | the valley.
# Processing Record 45  of Set 10 | mountain home.
# Processing Record 46  of Set 10 | lourdes.
# Processing Record 47  of Set 10 | tabarqah.
# City not found...skipping tabarqah.
# Processing Record 48  of Set 10 | eskasem.
# City not found...skipping eskasem.
# Processing Record 49  of Set 10 | saldanha.
# Processing Record 0  of Set 11 | karaton.
# Processing Record 1  of Set 11 | baykit.
# Processing Record 2  of Set 11 | eyl.
# Processing Record 3  of Set 11 | port hedland.
# Processing Record 4  of Set 11 | beloha.
# Processing Record 5  of Set 11 | dhamtari.
# Processing Record 6  of Set 11 | xuddur.
# Processing Record 7  of Set 11 | mambajao.
# Processing Record 8  of Set 11 | bowen.
# Processing Record 9  of Set 11 | lar.
# Processing Record 10  of Set 11 | andenes.
# City not found...skipping andenes.
# Processing Record 11  of Set 11 | norman wells.
# Processing Record 12  of Set 11 | mugla.
# Processing Record 13  of Set 11 | kungurtug.
# Processing Record 14  of Set 11 | rawson.
# Processing Record 15  of Set 11 | rorvik.
# Processing Record 16  of Set 11 | pias.
# Processing Record 17  of Set 11 | saint-joseph.
# Processing Record 18  of Set 11 | arlit.
# Processing Record 19  of Set 11 | merauke.
# Processing Record 20  of Set 11 | lompoc.
# Processing Record 21  of Set 11 | eureka.
# Processing Record 22  of Set 11 | srednekolymsk.
# Processing Record 23  of Set 11 | dubbo.
# Processing Record 24  of Set 11 | moindou.
# Processing Record 25  of Set 11 | sechura.
# Processing Record 26  of Set 11 | faanui.
# Processing Record 27  of Set 11 | dzhebariki-khaya.
# Processing Record 28  of Set 11 | inuvik.
# Processing Record 29  of Set 11 | menongue.
# Processing Record 30  of Set 11 | niquelandia.
# Processing Record 31  of Set 11 | dafeng.
# Processing Record 32  of Set 11 | bom sucesso.
# Processing Record 33  of Set 11 | pandan.
# Processing Record 34  of Set 11 | harper.
# Processing Record 35  of Set 11 | sorkjosen.
# City not found...skipping sorkjosen.
# Processing Record 36  of Set 11 | turukhansk.
# Processing Record 37  of Set 11 | san rafael.
# Processing Record 38  of Set 11 | saint-georges.
# Processing Record 39  of Set 11 | murakami.
# Processing Record 40  of Set 11 | kupang.
# Processing Record 41  of Set 11 | mackay.
# Processing Record 42  of Set 11 | harer.
# Processing Record 43  of Set 11 | horsham.
# Processing Record 44  of Set 11 | hambantota.
# Processing Record 45  of Set 11 | praia da vitoria.
# Processing Record 46  of Set 11 | rapar.
# Processing Record 47  of Set 11 | guymon.
# Processing Record 48  of Set 11 | nelson bay.
# Processing Record 49  of Set 11 | opoczno.
# Processing Record 0  of Set 12 | zhaotong.
# Processing Record 1  of Set 12 | amboasary.
# Processing Record 2  of Set 12 | guanambi.
# Processing Record 3  of Set 12 | bonavista.
# Processing Record 4  of Set 12 | pachino.
# Processing Record 5  of Set 12 | dzaoudzi.
# Processing Record 6  of Set 12 | bargal.
# City not found...skipping bargal.
# Processing Record 7  of Set 12 | huamachuco.
# Processing Record 8  of Set 12 | rawah.
# City not found...skipping rawah.
# Processing Record 9  of Set 12 | puerto escondido.
# Processing Record 10  of Set 12 | guiratinga.
# Processing Record 11  of Set 12 | camargo.
# Processing Record 12  of Set 12 | manavgat.
# Processing Record 13  of Set 12 | hushitai.
# Processing Record 14  of Set 12 | hualahuises.
# Processing Record 15  of Set 12 | whitehorse.
# Processing Record 16  of Set 12 | jaru.
# Processing Record 17  of Set 12 | joacaba.
# Processing Record 18  of Set 12 | bentiu.
# City not found...skipping bentiu.
# Processing Record 19  of Set 12 | chulym.
# Processing Record 20  of Set 12 | noumea.
# Processing Record 21  of Set 12 | sakaiminato.
# Processing Record 22  of Set 12 | luanda.
# Processing Record 23  of Set 12 | buta.
# Processing Record 24  of Set 12 | lichinga.
# Processing Record 25  of Set 12 | ushtobe.
# Processing Record 26  of Set 12 | ballina.
# Processing Record 27  of Set 12 | jaspur.
# Processing Record 28  of Set 12 | we.
# City not found...skipping we.
# Processing Record 29  of Set 12 | sanary-sur-mer.
# Processing Record 30  of Set 12 | tumannyy.
# City not found...skipping tumannyy.
# Processing Record 31  of Set 12 | sur.
# Processing Record 32  of Set 12 | najran.
# Processing Record 33  of Set 12 | sao joao da ponte.
# Processing Record 34  of Set 12 | dingle.
# Processing Record 35  of Set 12 | besikduzu.
# Processing Record 36  of Set 12 | ceres.
# Processing Record 37  of Set 12 | vila franca do campo.
# Processing Record 38  of Set 12 | sao joao da barra.
# Processing Record 39  of Set 12 | elmadag.
# Processing Record 40  of Set 12 | padang.
# Processing Record 41  of Set 12 | dunedin.
# Processing Record 42  of Set 12 | lagos.
# Processing Record 43  of Set 12 | sungaipenuh.
# Processing Record 44  of Set 12 | chlumec.
# Processing Record 45  of Set 12 | san jose.
# Processing Record 46  of Set 12 | sistranda.
# Processing Record 47  of Set 12 | aripuana.
# Processing Record 48  of Set 12 | paramonga.
# Processing Record 49  of Set 12 | balod.
# Processing Record 0  of Set 13 | trat.
# Processing Record 1  of Set 13 | irbil.
# City not found...skipping irbil.
# Processing Record 2  of Set 13 | rocky mountain house.
# Processing Record 3  of Set 13 | cidreira.
# Processing Record 4  of Set 13 | tougue.
# Processing Record 5  of Set 13 | warah.
# Processing Record 6  of Set 13 | gigante.
# Processing Record 7  of Set 13 | den helder.
# Processing Record 8  of Set 13 | freetown.
# Processing Record 9  of Set 13 | lahij.
# Processing Record 10  of Set 13 | birao.
# Processing Record 11  of Set 13 | susangerd.
# Processing Record 12  of Set 13 | finnsnes.
# Processing Record 13  of Set 13 | mecca.
# Processing Record 14  of Set 13 | caramay.
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Data Count
weather_df.count()
# Out:
# City                615
# Country             615
# Date                615
# Latitude            615
# Longitude           615
# Cloudiness (%)      615
# Humidity (%)        615
# Max Temp (F)        615
# Wind Speed (mph)    615
# dtype: int64

# %%
# Display DataFrame
weather_df.head()
# Out:
#           City Country                 Date Latitude Longitude Cloudiness (%)  \
# 0  san quintin      PH  2019-09-25 16:03:32    17.54    120.52             44
# 1      rikitea      PF  2019-09-25 16:01:38   -23.12   -134.97              0
# 2     katsuura      JP  2019-09-25 16:03:01    33.93     134.5             20
# 3      mataura      NZ  2019-09-25 16:01:34   -46.19    168.86            100
# 4       camopi      GF  2019-09-25 16:03:32     3.17    -52.33            100
#
#   Humidity (%) Max Temp (F) Wind Speed (mph)
# 0           81      72.3038              1.6
# 1           68      71.9978             3.59
# 2           82        66.47              3.6
# 3           85       44.276             8.94
# 4           46      87.1358             2.31

# %%
# Convert data strings to float
pd.to_numeric(weather_df["Cloudiness (%)"]).astype(float)
pd.to_numeric(weather_df["Humidity (%)"]).astype(float)
pd.to_numeric(weather_df["Latitude"]).astype(float)
pd.to_numeric(weather_df["Longitude"]).astype(float)
pd.to_numeric(weather_df["Max Temp (F)"]).astype(float)
pd.to_numeric(weather_df["Wind Speed (mph)"]).astype(float)
weather_df

#Export DataFrame to CSV File
weather_df.to_csv("weather_df.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Max Temp (F)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title(f"City Latitude vs Max Temperature ({today})")
print("The plot proves that as we generally move away from the equator, temperature drops")
# Out:
# The plot proves that as we generally move away from the equator, temperature drops

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Humidity (%)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs Humidity (%) ({today})")
print("The plot shows that there is no real pattern that can describe the relationship between latitude and humidity")
# Out:
# The plot shows that there is no real pattern that can describe the relationship between latitude and humidity

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Cloudiness (%)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs Cloudiness ({today})")
print("The plot shows that there is no real pattern that can describe the relationship between latitude and cloudiness")
# Out:
# The plot shows that there is no real pattern that can describe the relationship between latitude and cloudiness

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Wind Speed (mph)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"City Latitude vs Wind Speed ({today})")
print("The plot shows that there is no real pattern that can describe the relationship between latitude and windspeed")
# Out:
# The plot shows that there is no real pattern that can describe the relationship between latitude and windspeed

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_df = weather_df.loc[pd.to_numeric(weather_df["Latitude"]).astype(float) > 0, :]
southern_df = weather_df.loc[pd.to_numeric(weather_df["Latitude"]).astype(float) < 0, :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Max Temp (F)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a negative correlation.")
print("In the nothern hemisphere, as you move away from the equator the temperature decreases.")
plt.show()
# Out:
# Regression line equation is: y = -0.74x + 92.57
# The r-squared is: -0.8028694753221505
# The regression displays a negative correlation.
# In the nothern hemisphere, as you move away from the equator the temperature decreases.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Max Temp (F)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a positive correlation.")
print("In the southern hemisphere, as you get closer to the equator the temperature increases.")
plt.show()
# Out:
# Regression line equation is: y = 0.59x + 80.27
# The r-squared is: 0.6557952675136837
# The regression displays a positive correlation.
# In the southern hemisphere, as you get closer to the equator the temperature increases.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Humidity (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.") 
plt.show()
# Out:
# Regression line equation is: y = 0.2x + 63.92
# The r-squared is: 0.18543275902405895
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Humidity (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.47x + 79.74
# The r-squared is: 0.2216209384639038
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Cloudiness (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.2x + 42.01
# The r-squared is: 0.10118522354150992
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Cloudiness (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.54x + 59.52
# The r-squared is: 0.1939518555616875
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Wind Speed (mph)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.0x + 3.26
# The r-squared is: 0.04078748142287392
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Wind Speed (mph)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = -0.06x + 2.72
# The r-squared is: -0.28658920705671076
# The regression does not display much of a correlation between the data sets.
